# %%
import pandas as pd

# %%
pangkat = pd.read_csv('pangkat.csv')

# %%
data = pangkat.copy()

# %%
target = 'pangkat'

# %%
encode = ['pend_terakhir']

# %%
data
# Out:
#      pangkat pend_terakhir  thn_pengangkatan  usia_asn  masa_kerja
# 0       IV/d            S2              1995        60          28
# 1       IV/c            S1              1992        58          31
# 2       IV/c            S1              1988        60          35
# 3       IV/c            S1              1988        56          35
# 4       IV/c            S2              1993        56          30
# ...      ...           ...               ...       ...         ...
# 5444    II/c            D3              2007        53          16
# 5445    II/c            D3              2012        43          11
# 5446    II/c            D3              2014        45           9
# 5447    II/c            D3              2014        41           9
# 5448    II/c            D3              2014        42           9
#
# [5449 rows x 5 columns]

# %%
for col in encode:
  dummy = pd.get_dummies(data[col], prefix=col)
  data = pd.concat([data,dummy], axis=1)
  del data[col]

# %%
data
# Out:
#      pangkat  thn_pengangkatan  usia_asn  masa_kerja  pend_terakhir_D3  \
# 0       IV/d              1995        60          28                 0
# 1       IV/c              1992        58          31                 0
# 2       IV/c              1988        60          35                 0
# 3       IV/c              1988        56          35                 0
# 4       IV/c              1993        56          30                 0
# ...      ...               ...       ...         ...               ...
# 5444    II/c              2007        53          16                 1
# 5445    II/c              2012        43          11                 1
# 5446    II/c              2014        45           9                 1
# 5447    II/c              2014        41           9                 1
# 5448    II/c              2014        42           9                 1
#
#       pend_terakhir_S1  pend_terakhir_S2
# 0                    0                 1
# ...

# %%
target_mapper = {'I/d':0, 'II/a':1, 'II/b':2, 'II/c':3, 'II/d':4, 'III/a':5, 'III/b':6,
                 'III/c':7, 'III/d':8, 'IV/a':9, 'IV/b':10, 'IV/c':11, 'IV/d':12}

# %%
def target_encode(val):
  return target_mapper[val]

# %%
data['pangkat'] = data['pangkat'].apply(target_encode)

# %%
data
# Out:
#       pangkat  thn_pengangkatan  usia_asn  masa_kerja  pend_terakhir_D3  \
# 0          12              1995        60          28                 0
# 1          11              1992        58          31                 0
# 2          11              1988        60          35                 0
# 3          11              1988        56          35                 0
# 4          11              1993        56          30                 0
# ...       ...               ...       ...         ...               ...
# 5444        3              2007        53          16                 1
# 5445        3              2012        43          11                 1
# 5446        3              2014        45           9                 1
# 5447        3              2014        41           9                 1
# 5448        3              2014        42           9                 1
#
#       pend_terakhir_S1  pend_terakhir_S2
# 0                    0                 1
# ...

# %%
X = data.drop('pangkat', axis=1)
Y = data['pangkat']

# %%
X
# Out:
#       thn_pengangkatan  usia_asn  masa_kerja  pend_terakhir_D3  \
# 0                 1995        60          28                 0
# 1                 1992        58          31                 0
# 2                 1988        60          35                 0
# 3                 1988        56          35                 0
# 4                 1993        56          30                 0
# ...                ...       ...         ...               ...
# 5444              2007        53          16                 1
# 5445              2012        43          11                 1
# 5446              2014        45           9                 1
# 5447              2014        41           9                 1
# 5448              2014        42           9                 1
#
#       pend_terakhir_S1  pend_terakhir_S2
# 0                    0                 1
# 1                    1                 0
# 2                    1                 0
# 3                    1                 0
# ...

# %%
Y
# Out:
# 0       12
# 1       11
# 2       11
# 3       11
# 4       11
#         ..
# 5444     3
# 5445     3
# 5446     3
# 5447     3
# 5448     3
# Name: pangkat, Length: 5449, dtype: int64

# %%
# MODEL NAIVE BAYES CLASSIFIER (NBC)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X,Y)
# Out:
# GaussianNB()

# %%
# MENYIMPAN MODEL NAIVE BAYES CLASSIFIER (NBC)
import pickle
pickle.dump(model, open('modelNBC_pangkat.pkl', 'wb')) #wb untuk menyimpan
